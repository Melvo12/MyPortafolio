# %%
# Step by step of how the Toy sales Dashboard project was carried out
# For this only in this project BI prower was used

# %%
# We load the data into power BI. The file name is Row_data.xlsx
# We observe that the data have a lot of null cells. We need to click on view and then colum quality.
# we delete the 4 first rows

# %% [markdown]
# ![1-2.png](attachment:1-2.png)

# %%
# we delete the 4 first rows because it is specific data for all the data base that we can use later
# Then we see if all the data is 100% complete without no errors

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %%
# now we need to split the data and you can do this by creation an index for the columns Store Name,Region and Store Type

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
# Now to make our model we make the relationship between our columns

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
# we create a new table and we add that to the model
Calendar = ADDCOLUMNS(CALENDARAUTO(), "Year", YEAR([Date]),"Month",FORMAT([Date],"mmm" ),"Month num", MONTH([Date]),"quarter", FORMAT([Date], "\QQ"),"weekdays", FORMAT([Date],"ddd"), "week num", WEEKDAY([Date]))

# %% [markdown]
# ![5.png](attachment:5.png)
